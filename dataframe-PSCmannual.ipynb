# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Perovskite_database_content_all_data.csv")
# Out:
# D:\ProgramData\Anaconda3\envs\py37\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (10,22,29,31,32,35,36,40,44,45,46,48,51,54,65,84,89,90,93,98,99,100,105,108,115,118,122,123,125,130,134,138,142,143,144,146,149,152,163,166,167,171,172,173,175,178,181,192,194,225,271,272,273,277,304,315,321,325,330,331,335,336,342,348,369,371,373,374,376,380,384,387,403,405,407,409) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df)
# Out:
#        Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 0           1            1                       Adam Hultqvist
# 1           2            2                       Adam Hultqvist
# 2           3            3                       Adam Hultqvist
# 3           4            4                       Adam Hultqvist
# 4           5            5                       Adam Hultqvist
# ...       ...          ...                                  ...
# 42492   42497           37                      Timothy Siegler
# 42493   42485           25                      Timothy Siegler
# 42494   42488           28                      Timothy Siegler
# 42495   42491           31                      Timothy Siegler
# 42496   42472           12                                  NaN
#
#        Ref_data_entered_by_author          Ref_DOI_number  Ref_lead_author  \
# 0                           False       10.1021/jp5126624     Sabba et al.
# ...

# %%
df.shape
# Out:
# (42497, 410)

# %%
df.head(10)
# Out:
#    Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 0       1            1                       Adam Hultqvist
# 1       2            2                       Adam Hultqvist
# 2       3            3                       Adam Hultqvist
# 3       4            4                       Adam Hultqvist
# 4       5            5                       Adam Hultqvist
# 5       6            6                       Adam Hultqvist
# 6       7            7                       Adam Hultqvist
# 7       8            8                       Adam Hultqvist
# 8       9            9                       Adam Hultqvist
# 9      10           10                       Adam Hultqvist
#
#    Ref_data_entered_by_author                   Ref_DOI_number  \
# 0                       False                10.1021/jp5126624
# 1                       False                10.1021/jp5126624
# 2                       False                10.1021/jp5126624
# ...

# %%
df.tail(3)
# Out:
#        Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 42494   42488           28                      Timothy Siegler
# 42495   42491           31                      Timothy Siegler
# 42496   42472           12                                  NaN
#
#        Ref_data_entered_by_author          Ref_DOI_number  Ref_lead_author  \
# 42494                        True  10.1021/acsaem.9b01298  Siegler et. al.
# 42495                        True  10.1021/acsaem.9b01298  Siegler et. al.
# 42496                       False                     NaN              NaN
#
#       Ref_publication_date Ref_journal  Ref_part_of_initial_dataset  \
# 42494           2019-07-12           -                        False
# 42495           2019-07-12           -                        False
# 42496           2022-04-11           -                        False
#
#       Ref_original_filename_data_upload  ... Outdoor_PCE_Tse80  \
# 42494               2022-04-05 _v1.xlsx  ...               NaN
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=42497, step=1)

# %%
df.columns
# Out:
# Index(['Ref_ID', 'Ref_ID_temp', 'Ref_name_of_person_entering_the_data',
#        'Ref_data_entered_by_author', 'Ref_DOI_number', 'Ref_lead_author',
#        'Ref_publication_date', 'Ref_journal', 'Ref_part_of_initial_dataset',
#        'Ref_original_filename_data_upload',
#        ...
#        'Outdoor_PCE_Tse80', 'Outdoor_PCE_after_1000_h',
#        'Outdoor_power_generated', 'Outdoor_link_raw_data_for_outdoor_trace',
#        'Outdoor_detaild_weather_data_available',
#        'Outdoor_link_detailed_weather_data', 'Outdoor_spectral_data_available',
#        'Outdoor_link_spectral_data', 'Outdoor_irradiance_measured',
#        'Outdoor_link_irradiance_data'],
#       dtype='object', length=410)

# %%
df.describe()
# Out:
#              Ref_ID   Ref_ID_temp  Cell_area_total  Cell_area_measured  \
# count  42497.000000  42497.000000      1017.000000        41786.000000
# mean   21250.289668  21151.425206         0.987871            0.206617
# std    12269.727031  12269.447090         4.729307            5.302270
# min        1.000000      1.000000         0.007850            0.000120
# 25%    10625.000000  10526.000000         0.080000            0.090000
# 50%    21249.000000  21150.000000         0.100000            0.100000
# 75%    31873.000000  31774.000000         0.160000            0.120000
# max    42504.000000  42404.000000        43.250000         1063.000000
#
#        Cell_number_of_cells_per_substrate  Cell_flexible_min_bending_radius  \
# count                        42497.000000                               0.0
# mean                             0.019131                               NaN
# std                              0.481184                               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42497 entries, 0 to 42496
# Columns: 410 entries, Ref_ID to Outdoor_link_irradiance_data
# dtypes: bool(37), float64(112), int64(10), object(251)
# memory usage: 122.4+ MB

# %%
df.isnull().sum()
# Out:
# Ref_ID                                      0
# Ref_ID_temp                                 0
# Ref_name_of_person_entering_the_data        2
# Ref_data_entered_by_author                  0
# Ref_DOI_number                              2
#                                         ...
# Outdoor_link_detailed_weather_data      42496
# Outdoor_spectral_data_available             0
# Outdoor_link_spectral_data              42496
# Outdoor_irradiance_measured                 0
# Outdoor_link_irradiance_data            42496
# Length: 410, dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 42492    False
# 42493    False
# 42494    False
# 42495    False
# 42496    False
# Length: 42497, dtype: bool

# %%
df.iloc[0:1,0:410]
# Out:
#    Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 0       1            1                       Adam Hultqvist
#
#    Ref_data_entered_by_author     Ref_DOI_number Ref_lead_author  \
# 0                       False  10.1021/jp5126624    Sabba et al.
#
#   Ref_publication_date                          Ref_journal  \
# 0           2015-01-06  The Journal of Physical Chemistry C
#
#    Ref_part_of_initial_dataset       Ref_original_filename_data_upload  \
# 0                         True  Historic dataset on 2020 11 22_v7.xlsx
#
#   Ref_free_text_comment Ref_internal_sample_id  \
# 0                   NaN                    NaN
#
#                                  Cell_stack_sequence  Cell_area_total  \
# 0  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...              NaN
#
#    Cell_area_measured  Cell_number_of_cells_per_substrate Cell_architecture  \
# 0                 0.2                                   0               nip
#
# ...

# %%
pd.options.display.max_columns = None

# %%
df.head(3)
# Out:
#    Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 0       1            1                       Adam Hultqvist
# 1       2            2                       Adam Hultqvist
# 2       3            3                       Adam Hultqvist
#
#    Ref_data_entered_by_author     Ref_DOI_number Ref_lead_author  \
# 0                       False  10.1021/jp5126624    Sabba et al.
# 1                       False  10.1021/jp5126624    Sabba et al.
# 2                       False  10.1021/jp5126624    Sabba et al.
#
#   Ref_publication_date                          Ref_journal  \
# 0           2015-01-06  The Journal of Physical Chemistry C
# 1           2015-01-06  The Journal of Physical Chemistry C
# 2           2015-01-06  The Journal of Physical Chemistry C
#
#    Ref_part_of_initial_dataset       Ref_original_filename_data_upload  \
# 0                         True  Historic dataset on 2020 11 22_v7.xlsx
# ...

# %%
df.loc[:,"Cell_stack_sequence"]
# Out:
# 0        SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 1        SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 2        SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 3        SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 4        SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
#                                ...
# 42492    SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42493    SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42494    SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42495    SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42496                                              Unknown
# Name: Cell_stack_sequence, Length: 42497, dtype: object

# %%
df.loc[:,["Cell_stack_sequence","Substrate_stack_sequence","ETL_stack_sequence","ETL_thickness","ETL_additives_compounds","ETL_additives_concentrations","ETL_deposition_procedure","Perovskite_composition_a_ions","Perovskite_composition_a_ions_coefficients","Perovskite_composition_b_ions","Perovskite_composition_b_ions_coefficients","Perovskite_composition_c_ions","Perovskite_composition_c_ions_coefficients","Perovskite_composition_short_form","Perovskite_composition_long_form","Perovskite_additives_compounds","Perovskite_additives_concentrations","Perovskite_thickness","Perovskite_band_gap","Perovskite_deposition_procedure","Perovskite_deposition_solvents","Perovskite_deposition_solvents_mixing_ratios","Perovskite_deposition_thermal_annealing_temperature","Perovskite_deposition_thermal_annealing_time","HTL_stack_sequence","HTL_thickness_list","HTL_additives_compounds","Backcontact_stack_sequence","Backcontact_thickness_list","Backcontact_deposition_procedure","JV_light_intensity","JV_light_spectra","JV_reverse_scan_Voc","JV_reverse_scan_Jsc","JV_reverse_scan_FF","JV_reverse_scan_PCE","JV_forward_scan_Voc","JV_forward_scan_Jsc","JV_forward_scan_FF","JV_forward_scan_PCE","JV_default_Voc","JV_default_Jsc","JV_default_FF","JV_default_PCE","Stability_average_over_n_number_of_cells"]]
# Out:
#                                      Cell_stack_sequence  \
# 0      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 1      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 2      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 3      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 4      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# ...                                                  ...
# 42492  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42493  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42494  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42495  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42496                                            Unknown
#
#       Substrate_stack_sequence ETL_stack_sequence ETL_thickness  \
# 0                    SLG | FTO   TiO2-c | TiO2-mp    65.0 | nan
# 1                    SLG | FTO   TiO2-c | TiO2-mp    65.0 | nan
# 2                    SLG | FTO   TiO2-c | TiO2-mp    65.0 | nan
# ...

# %%
df.loc[:,["Cell_stack_sequence","Substrate_stack_sequence","ETL_stack_sequence","ETL_thickness","ETL_additives_compounds","ETL_additives_concentrations","ETL_deposition_procedure","Perovskite_composition_a_ions","Perovskite_composition_a_ions_coefficients","Perovskite_composition_b_ions","Perovskite_composition_b_ions_coefficients","Perovskite_composition_c_ions","Perovskite_composition_c_ions_coefficients","Perovskite_composition_short_form","Perovskite_composition_long_form","Perovskite_additives_compounds","Perovskite_additives_concentrations","Perovskite_thickness","Perovskite_band_gap","Perovskite_deposition_procedure","Perovskite_deposition_solvents","Perovskite_deposition_solvents_mixing_ratios","Perovskite_deposition_thermal_annealing_temperature","Perovskite_deposition_thermal_annealing_time","HTL_stack_sequence","HTL_thickness_list","HTL_additives_compounds","Backcontact_stack_sequence","Backcontact_thickness_list","Backcontact_deposition_procedure","JV_light_intensity","JV_light_spectra","JV_reverse_scan_Voc","JV_reverse_scan_Jsc","JV_reverse_scan_FF","JV_reverse_scan_PCE","JV_forward_scan_Voc","JV_forward_scan_Jsc","JV_forward_scan_FF","JV_forward_scan_PCE","JV_default_Voc","JV_default_Jsc","JV_default_FF","JV_default_PCE","Stability_average_over_n_number_of_cells"]]
# Out:
#                                      Cell_stack_sequence  \
# 0      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 1      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 2      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 3      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 4      SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# ...                                                  ...
# 42492  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42493  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42494  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42495  SLG | FTO | TiO2-c | TiO2-mp | Perovskite | Sp...
# 42496                                            Unknown
#
#       Substrate_stack_sequence ETL_stack_sequence ETL_thickness  \
# 0                    SLG | FTO   TiO2-c | TiO2-mp    65.0 | nan
# 1                    SLG | FTO   TiO2-c | TiO2-mp    65.0 | nan
# 2                    SLG | FTO   TiO2-c | TiO2-mp    65.0 | nan
# ...

# %%
df.loc[:,["Cell_stack_sequence","Substrate_stack_sequence","ETL_stack_sequence","ETL_thickness","ETL_additives_compounds","ETL_additives_concentrations","ETL_deposition_procedure","Perovskite_composition_a_ions","Perovskite_composition_a_ions_coefficients","Perovskite_composition_b_ions","Perovskite_composition_b_ions_coefficients","Perovskite_composition_c_ions","Perovskite_composition_c_ions_coefficients","Perovskite_composition_short_form","Perovskite_composition_long_form","Perovskite_additives_compounds","Perovskite_additives_concentrations","Perovskite_thickness","Perovskite_band_gap","Perovskite_deposition_procedure","Perovskite_deposition_solvents","Perovskite_deposition_solvents_mixing_ratios","Perovskite_deposition_thermal_annealing_temperature","Perovskite_deposition_thermal_annealing_time","HTL_stack_sequence","HTL_thickness_list","HTL_additives_compounds","Backcontact_stack_sequence","Backcontact_thickness_list","Backcontact_deposition_procedure","JV_light_intensity","JV_light_spectra","JV_reverse_scan_Voc","JV_reverse_scan_Jsc","JV_reverse_scan_FF","JV_reverse_scan_PCE","JV_forward_scan_Voc","JV_forward_scan_Jsc","JV_forward_scan_FF","JV_forward_scan_PCE","JV_default_Voc","JV_default_Jsc","JV_default_FF","JV_default_PCE","Stability_average_over_n_number_of_cells"]].to_csv('ImportantInputOutput.csv', index=False)

# %%
json_data=pd.read_json('psc_rsc.json',lines=True)

# %%
json_data.head(3)
# Out:
#                                     _id  \
# 0  {'$oid': '5f1ff759996869675038bdd1'}
# 1  {'$oid': '5f1ff759996869675038bdd2'}
# 2  {'$oid': '5f1ff759996869675038bdd3'}
#
#                               device_characteristics  \
# 0  {'voc': {'raw_value': '851 ± 20', 'raw_units':...
# 1  {'voc': {'raw_value': '859 ± 15', 'raw_units':...
# 2  {'voc': {'raw_value': '868 ± 20', 'raw_units':...
#
#                              psc_material_components  \
# 0  {'perovskite': {'specifier': 'perovskite', 'ra...
# 1  {'perovskite': {'specifier': 'perovskite', 'ra...
# 2  {'perovskite': {'specifier': 'perovskite', 'ra...
#
#                                     device_metrology psc_material_metrology  \
# 0  {'solar_simulator': {'raw_value': '100', 'raw_...                     {}
# 1  {'solar_simulator': {'raw_value': '100', 'raw_...                     {}
# 2  {'solar_simulator': {'raw_value': '100', 'raw_...                     {}
#
# ...

# %%
json_data.shape
# Out:
# (7559, 8)

# %%
json_data.columns
# Out:
# Index(['_id', 'device_characteristics', 'psc_material_components',
#        'device_metrology', 'psc_material_metrology', 'table_data',
#        'device_reference', 'article_info'],
#       dtype='object')

# %%
json_data.tail
# Out:
# <bound method NDFrame.tail of                                        _id  \
# 0     {'$oid': '5f1ff759996869675038bdd1'}
# 1     {'$oid': '5f1ff759996869675038bdd2'}
# 2     {'$oid': '5f1ff759996869675038bdd3'}
# 3     {'$oid': '5f1ff759996869675038bdd4'}
# 4     {'$oid': '5f1ff75a996869675038bdd5'}
# ...                                    ...
# 7554  {'$oid': '5f1ff762996869675038db53'}
# 7555  {'$oid': '5f1ff762996869675038db54'}
# 7556  {'$oid': '5f1ff762996869675038db55'}
# 7557  {'$oid': '5f1ff762996869675038db56'}
# 7558  {'$oid': '5f1ff762996869675038db57'}
#
#                                  device_characteristics  \
# 0     {'voc': {'raw_value': '851 ± 20', 'raw_units':...
# 1     {'voc': {'raw_value': '859 ± 15', 'raw_units':...
# 2     {'voc': {'raw_value': '868 ± 20', 'raw_units':...
# 3     {'voc': {'raw_value': '877 ± 17', 'raw_units':...
# 4     {'voc': {'raw_value': '0.95', 'raw_units': '[V...
# ...                                                 ...
# ...

# %%
json_data.index
# Out:
# RangeIndex(start=0, stop=7559, step=1)

# %%
json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7559 entries, 0 to 7558
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   _id                      7559 non-null   object
#  1   device_characteristics   7559 non-null   object
#  2   psc_material_components  7559 non-null   object
#  3   device_metrology         7559 non-null   object
#  4   psc_material_metrology   7559 non-null   object
#  5   table_data               7559 non-null   object
#  6   device_reference         7559 non-null   object
#  7   article_info             7559 non-null   object
# dtypes: object(8)
# memory usage: 472.6+ KB

# %%
json_data.shape
# Out:
# (7559, 8)

# %%
json_data.tail(100)
# Out:
#                                        _id  \
# 7459  {'$oid': '5f1ff762996869675038daf4'}
# 7460  {'$oid': '5f1ff762996869675038daf5'}
# 7461  {'$oid': '5f1ff762996869675038daf6'}
# 7462  {'$oid': '5f1ff762996869675038daf7'}
# 7463  {'$oid': '5f1ff762996869675038daf8'}
# ...                                    ...
# 7554  {'$oid': '5f1ff762996869675038db53'}
# 7555  {'$oid': '5f1ff762996869675038db54'}
# 7556  {'$oid': '5f1ff762996869675038db55'}
# 7557  {'$oid': '5f1ff762996869675038db56'}
# 7558  {'$oid': '5f1ff762996869675038db57'}
#
#                                  device_characteristics  \
# 7459  {'voc': {'raw_value': '0.69', 'raw_units': '(V...
# 7460  {'voc': {'raw_value': '0.70', 'raw_units': '(V...
# 7461  {'voc': {'raw_value': '0.72', 'raw_units': '(V...
# 7462  {'voc': {'raw_value': '0.73', 'raw_units': '(V...
# 7463  {'voc': {'raw_value': '0.75', 'raw_units': '(V...
# ...                                                 ...
# ...

# %%
pd.options.display.max_columns=None

# %%
json_data.head(10)
# Out:
#                                     _id  \
# 0  {'$oid': '5f1ff759996869675038bdd1'}
# 1  {'$oid': '5f1ff759996869675038bdd2'}
# 2  {'$oid': '5f1ff759996869675038bdd3'}
# 3  {'$oid': '5f1ff759996869675038bdd4'}
# 4  {'$oid': '5f1ff75a996869675038bdd5'}
# 5  {'$oid': '5f1ff75a996869675038bdd6'}
# 6  {'$oid': '5f1ff75a996869675038bdd7'}
# 7  {'$oid': '5f1ff75a996869675038bdd8'}
# 8  {'$oid': '5f1ff75a996869675038bdd9'}
# 9  {'$oid': '5f1ff75a996869675038bdda'}
#
#                               device_characteristics  \
# 0  {'voc': {'raw_value': '851 ± 20', 'raw_units':...
# 1  {'voc': {'raw_value': '859 ± 15', 'raw_units':...
# 2  {'voc': {'raw_value': '868 ± 20', 'raw_units':...
# 3  {'voc': {'raw_value': '877 ± 17', 'raw_units':...
# 4  {'voc': {'raw_value': '0.95', 'raw_units': '[V...
# 5  {'voc': {'raw_value': '0.89', 'raw_units': '[V...
# 6  {'voc': {'raw_value': '0.92', 'raw_units': '[V...
# 7  {'voc': {'raw_value': '0.63', 'raw_units': '(V...
# ...

# %%
np.set_printoptions(threshold = np.inf)
#若想不以科学计数显示:
np.set_printoptions(suppress = True)

# %%
json_data.head(10)
# Out:
#                                     _id  \
# 0  {'$oid': '5f1ff759996869675038bdd1'}
# 1  {'$oid': '5f1ff759996869675038bdd2'}
# 2  {'$oid': '5f1ff759996869675038bdd3'}
# 3  {'$oid': '5f1ff759996869675038bdd4'}
# 4  {'$oid': '5f1ff75a996869675038bdd5'}
# 5  {'$oid': '5f1ff75a996869675038bdd6'}
# 6  {'$oid': '5f1ff75a996869675038bdd7'}
# 7  {'$oid': '5f1ff75a996869675038bdd8'}
# 8  {'$oid': '5f1ff75a996869675038bdd9'}
# 9  {'$oid': '5f1ff75a996869675038bdda'}
#
#                               device_characteristics  \
# 0  {'voc': {'raw_value': '851 ± 20', 'raw_units':...
# 1  {'voc': {'raw_value': '859 ± 15', 'raw_units':...
# 2  {'voc': {'raw_value': '868 ± 20', 'raw_units':...
# 3  {'voc': {'raw_value': '877 ± 17', 'raw_units':...
# 4  {'voc': {'raw_value': '0.95', 'raw_units': '[V...
# 5  {'voc': {'raw_value': '0.89', 'raw_units': '[V...
# 6  {'voc': {'raw_value': '0.92', 'raw_units': '[V...
# 7  {'voc': {'raw_value': '0.63', 'raw_units': '(V...
# ...

# %%
pd.options.display.max_rows=None

# %%
pd.set_option('max_colwidth',750)

# %%
json_data.head(100)
# Out:
#                                      _id  \
# 0   {'$oid': '5f1ff759996869675038bdd1'}
# 1   {'$oid': '5f1ff759996869675038bdd2'}
# 2   {'$oid': '5f1ff759996869675038bdd3'}
# 3   {'$oid': '5f1ff759996869675038bdd4'}
# 4   {'$oid': '5f1ff75a996869675038bdd5'}
# 5   {'$oid': '5f1ff75a996869675038bdd6'}
# 6   {'$oid': '5f1ff75a996869675038bdd7'}
# 7   {'$oid': '5f1ff75a996869675038bdd8'}
# 8   {'$oid': '5f1ff75a996869675038bdd9'}
# 9   {'$oid': '5f1ff75a996869675038bdda'}
# 10  {'$oid': '5f1ff75a996869675038bddb'}
# 11  {'$oid': '5f1ff75a996869675038bddc'}
# 12  {'$oid': '5f1ff75a996869675038bddd'}
# 13  {'$oid': '5f1ff75a996869675038bdde'}
# 14  {'$oid': '5f1ff75a996869675038bddf'}
# 15  {'$oid': '5f1ff75a996869675038bde0'}
# 16  {'$oid': '5f1ff75a996869675038bde1'}
# 17  {'$oid': '5f1ff75a996869675038bde2'}
# 18  {'$oid': '5f1ff75a996869675038bde3'}
# 19  {'$oid': '5f1ff75a996869675038bde4'}
# 20  {'$oid': '5f1ff75a996869675038bde5'}
# 21  {'$oid': '5f1ff75a996869675038bde6'}
# ...
